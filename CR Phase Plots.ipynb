# %% [markdown]
# # The First Stars: Formation under Cosmic Ray Feedback -- Phase Diagrams

# %% [markdown]
# This notebook generates all simulation results figures for my current paper.  All simulations run on stampede.tacc.utexas.edu

# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
mpl.rc('font', size=20.)
mpl.rc('font', family='serif')
mpl.rc('text', usetex=True)
import pyGadget

# %%
simV = pyGadget.sim.Simulation('stampede/vanilla',length='pc')
sim1 = pyGadget.sim.Simulation('stampede/cr_tau00',length='pc')
sim2 = pyGadget.sim.Simulation('stampede/cr_tau02',length='pc')
sim3 = pyGadget.sim.Simulation('stampede/cr_tau04',length='pc')

# %%
n0, n1, n2, n3, tag = 355, 289, 313, 210, '_t0'

# %%
snapV = simV.load_snapshot(n0, 'ndensity', 'temp', 'h2frac', 'HDfrac', 'electron_frac', 'coordinates')#,stride=1e5)
snap1 = sim1.load_snapshot(n1, 'ndensity', 'temp', 'h2frac', 'HDfrac', 'electron_frac','coordinates')#,stride=1e5)
snap2 = sim2.load_snapshot(n2, 'ndensity', 'temp', 'h2frac', 'HDfrac', 'electron_frac','coordinates')#,stride=1e5)
snap3 = sim3.load_snapshot(n3, 'ndensity', 'temp', 'h2frac', 'HDfrac', 'electron_frac','coordinates')#,stride=1e5)
# Out:
# Turning on gas particle refinement.
# There are
#  8000000 highest resolution particles.
# Loading data...
# ...
# Turning on gas particle refinement.
# There are
#  8000000 highest resolution particles.
# Loading data...
# ...
# Turning on gas particle refinement.
# There are
#  8000000 highest resolution particles.
# Loading data...
# ...
# Turning on gas particle refinement.
# There are
#  8000000 highest resolution particles.
# Loading data...
# ...

# %% [markdown]
# ## Density - Temperature phase diagram

# %%
fig = plt.figure(2, figsize=(16,12))
ax0 = fig.add_subplot(221)
ax1 = fig.add_subplot(222)
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224)
ax0 = pyGadget.multiplot.Phase.temp(snapV,ax0, rasterized=True)
ax1 = pyGadget.multiplot.Phase.temp(snap1,ax1, rasterized=True)
ax2 = pyGadget.multiplot.Phase.temp(snap2,ax2, rasterized=True)
ax3 = pyGadget.multiplot.Phase.temp(snap3,ax3, rasterized=True)

ax0.xaxis.set_visible(False)
ax1.xaxis.set_visible(False)
ax1.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax2.set_xticks((1e-2,1e0,1e2,1e4,1e6,1e8,1e10))
ax3.set_xticks((1e-2,1e0,1e2,1e4,1e6,1e8,1e10,1e12))
ax0.set_yticks((1e2,1e3,1e4))
ax2.set_yticks((10,1e2,1e3,1e4))

ax0.text(.97,.97, r'No Background', ha='right', va='top', size=25, transform=ax0.transAxes)
ax1.text(.97,.97, r'fiducial', ha='right', va='top', size=25, transform=ax1.transAxes)
ax2.text(.97,.97, r'10$^2$ fiducial', ha='right', va='top', size=25, transform=ax2.transAxes)
ax3.text(.97,.97, r'10$^4$ fiducial', ha='right', va='top', size=25, transform=ax3.transAxes)

plt.tight_layout(w_pad=0.0,h_pad=0.0)
fig.savefig('figures/phase_diagrams/temp'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ## H2 molecular fraction - density phase diagram

# %%
fig = plt.figure(3, figsize=(16,12))
ax0 = fig.add_subplot(221)
ax1 = fig.add_subplot(222)
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224)
ax0 = pyGadget.multiplot.Phase.h2frac(snapV,ax0)
ax1 = pyGadget.multiplot.Phase.h2frac(snap1,ax1)
ax2 = pyGadget.multiplot.Phase.h2frac(snap2,ax2)
ax3 = pyGadget.multiplot.Phase.h2frac(snap3,ax3)

ax0.xaxis.set_visible(False)
ax1.xaxis.set_visible(False)
ax1.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax2.set_xticks((1e-2,1e0,1e2,1e4,1e6,1e8,1e10))
ax3.set_xticks((1e-2,1e0,1e2,1e4,1e6,1e8,1e10,1e12))

ax0.text(.97,.97, r'No Background', ha='left', va='top', size=25, transform=ax0.transAxes)
ax1.text(.97,.97, r'fiducial', ha='left', va='top', size=25, transform=ax1.transAxes)
ax2.text(.97,.97, r'10$^2$ fiducial', ha='left', va='top', size=25, transform=ax2.transAxes)
ax3.text(.97,.97, r'10$^4$ fiducial', ha='left', va='top', size=25, transform=ax3.transAxes)

plt.tight_layout(w_pad=0.0,h_pad=0.0)
fig.savefig('figures/phase_diagrams/H2'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ## HD molecular fraction - density phase diagram

# %%
fig = plt.figure(3, figsize=(16,12))
ax0 = fig.add_subplot(221)
ax1 = fig.add_subplot(222)
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224)
ax0 = pyGadget.multiplot.Phase.HDfrac(snapV,ax0)
ax1 = pyGadget.multiplot.Phase.HDfrac(snap1,ax1)
ax2 = pyGadget.multiplot.Phase.HDfrac(snap2,ax2)
ax3 = pyGadget.multiplot.Phase.HDfrac(snap3,ax3)

ax0.xaxis.set_visible(False)
ax1.xaxis.set_visible(False)
ax1.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax2.set_xticks((1e-2,1e0,1e2,1e4,1e6,1e8,1e10))
ax3.set_xticks((1e-2,1e0,1e2,1e4,1e6,1e8,1e10,1e12))
ax2.set_yticks((1e-10,1e-9,1e-8,1e-7,1e-6,1e-5))

ax0.text(.97,.97, r'No Background', ha='left', va='top', size=25, transform=ax0.transAxes)
ax1.text(.97,.97, r'fiducial', ha='left', va='top', size=25, transform=ax1.transAxes)
ax2.text(.97,.97, r'10$^2$ fiducial', ha='left', va='top', size=25, transform=ax2.transAxes)
ax3.text(.97,.97, r'10$^4$ fiducial', ha='left', va='top', size=25, transform=ax3.transAxes)

plt.tight_layout(w_pad=0.0,h_pad=0.0)
fig.savefig('figures/phase_diagrams/HD'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ## Electron fraction - density phase diagram

# %%
fig = plt.figure(3, figsize=(16,12))
ax0 = fig.add_subplot(221)
ax1 = fig.add_subplot(222)
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224)
ax0 = pyGadget.multiplot.Phase.electron_frac(snapV,ax0)
ax1 = pyGadget.multiplot.Phase.electron_frac(snap1,ax1)
ax2 = pyGadget.multiplot.Phase.electron_frac(snap2,ax2)
ax3 = pyGadget.multiplot.Phase.electron_frac(snap3,ax3)

ax0.xaxis.set_visible(False)
ax1.xaxis.set_visible(False)
ax1.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax2.set_xticks((1e-2,1e0,1e2,1e4,1e6,1e8,1e10))
ax3.set_xticks((1e-2,1e0,1e2,1e4,1e6,1e8,1e10,1e12))
#ax2.set_yticks((1e-10,1e-9,1e-8,1e-7,1e-6,1e-5))

ax0.text(.97,.97, r'No Background', ha='right', va='top', size=25, transform=ax0.transAxes)
ax1.text(.97,.97, r'fiducial', ha='right', va='top', size=25, transform=ax1.transAxes)
ax2.text(.97,.97, r'10$^2$ fiducial', ha='right', va='top', size=25, transform=ax2.transAxes)
ax3.text(.97,.97, r'10$^4$ fiducial', ha='right', va='top', size=25, transform=ax3.transAxes)

plt.tight_layout(w_pad=0.0,h_pad=0.0)
fig.savefig('figures/phase_diagrams/elec'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ## Electron fraction - overlay

# %%
fig = plt.figure(3, figsize=(12,9))
ax = fig.add_subplot(111)
ax = pyGadget.multiplot.Phase.electron_frac(snapV,ax, cmap=plt.cm.Greys_r)
ax = pyGadget.multiplot.Phase.electron_frac(snap1,ax, cmap=plt.cm.Blues_r)
ax = pyGadget.multiplot.Phase.electron_frac(snap2,ax, cmap=plt.cm.Greens_r)
ax = pyGadget.multiplot.Phase.electron_frac(snap3,ax, cmap=plt.cm.Reds_r)

fig.savefig('figures/phase_diagrams/elec-overlay'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ## H2 fraction - overlay

# %%
fig = plt.figure(3, figsize=(12,9))
ax = fig.add_subplot(111)
ax = pyGadget.multiplot.Phase.h2frac(snapV,ax, cmap=plt.cm.Greys_r)
ax = pyGadget.multiplot.Phase.h2frac(snap1,ax, cmap=plt.cm.Blues_r)
ax = pyGadget.multiplot.Phase.h2frac(snap2,ax, cmap=plt.cm.Greens_r)
ax = pyGadget.multiplot.Phase.h2frac(snap3,ax, cmap=plt.cm.Reds_r)

fig.savefig('figures/phase_diagrams/h2-overlay'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ## HD fraction - overlay

# %%
fig = plt.figure(3, figsize=(12,9))
ax = fig.add_subplot(111)
ax = pyGadget.multiplot.Phase.HDfrac(snapV,ax, cmap=plt.cm.Greys_r)
ax = pyGadget.multiplot.Phase.HDfrac(snap1,ax, cmap=plt.cm.Blues_r)
ax = pyGadget.multiplot.Phase.HDfrac(snap2,ax, cmap=plt.cm.Greens_r)
ax = pyGadget.multiplot.Phase.HDfrac(snap3,ax, cmap=plt.cm.Reds_r)

fig.savefig('figures/phase_diagrams/HD-overlay'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ## Combination Overlay

# %%
snaplist = [snapV, snap1, snap2, snap3]
fig, axarr = plt.subplots(3,1, sharex=True, figsize=(8,17))
for i,func in enumerate([pyGadget.multiplot.Phase.electron_frac, pyGadget.multiplot.Phase.h2frac, pyGadget.multiplot.Phase.HDfrac]):
    for j, colormap in enumerate([plt.cm.Greys_r, plt.cm.Blues_r, plt.cm.Greens_r, plt.cm.Reds_r]):
        axarr[i] = func(snaplist[j], axarr[i], cmap=colormap)
        

#axarr[-1].set_xlabel('n [cm$^{-3}$]') 
plt.setp([a.get_yticklabels()[::2] for a in axarr], visible=False)
plt.setp(axarr[-1].get_xticklabels()[1::2], visible=False)
fig.subplots_adjust(hspace=0, wspace=0)
fig.savefig('figures/phase_diagrams/combo-overlay'+tag+'.png', bbox_inches='tight')

# %% [markdown]
# ## Halo Temperature vs Radius

# %%
fig = plt.figure(2, figsize=(16,12))
ax0 = fig.add_subplot(221)
ax1 = fig.add_subplot(222)
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224)
ax0 = pyGadget.multiplot.Phase.radial_temp(snapV,ax0)
ax1 = pyGadget.multiplot.Phase.radial_temp(snap1,ax1)
ax2 = pyGadget.multiplot.Phase.radial_temp(snap2,ax2)
ax3 = pyGadget.multiplot.Phase.radial_temp(snap3,ax3)

ax0.xaxis.set_visible(False)
ax1.xaxis.set_visible(False)
ax1.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax0.set_yticks((1e2,1e3,1e4))
ax2.set_yticks((10,1e2,1e3,1e4))

ax0.text(.03,.97, r'J = 0', ha='left', va='top', size=25, transform=ax0.transAxes)
ax1.text(.03,.97, r'J = J$_{0}$', ha='left', va='top', size=25, transform=ax1.transAxes)
ax2.text(.03,.97, r'J = J$_{0}$', ha='left', va='top', size=25, transform=ax2.transAxes)
ax3.text(.03,.97, r'J = J$_{0}$', ha='left', va='top', size=25, transform=ax3.transAxes)

plt.tight_layout(w_pad=0.0,h_pad=0.0)
fig.savefig('figures/phase_diagrams/radial_temp'+tag+'.png', bbox_inches='tight')
# Out:
# Center averaged over 4466 particles
# Center averaged over all particles with density greater than 1.00e+08 particles/cc
# Density averaged box center: 2.761e+03 2.757e+03 2.722e+03
# Center averaged over 4466 particles
# Center averaged over all particles with density greater than 1.00e+08 particles/cc
# Density averaged box center: 2.981e-01 -3.840e-01 -5.619e-01
# Center averaged over 5568 particles
# Center averaged over all particles with density greater than 1.00e+08 particles/cc
# Density averaged box center: 2.761e+03 2.757e+03 2.723e+03
# Center averaged over 5568 particles
# Center averaged over all particles with density greater than 1.00e+08 particles/cc
# Density averaged box center: 1.072e-01 -3.724e-01 -9.108e-01
# Center averaged over 11966 particles
# Center averaged over all particles with density greater than 1.00e+08 particles/cc
# Density averaged box center: 2.765e+03 2.761e+03 2.727e+03
# Center averaged over 11966 particles
# ...
