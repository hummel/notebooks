# %% [markdown]
# # The First Stars: Formation under X-ray Feedback -- Structure Visualization

# %% [markdown]
# This notebook generates all simulation results figures for my current paper.  All simulations run on stampede.tacc.utexas.edu

# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
mpl.rc('font', size=20.)
mpl.rc('font', family='serif')
mpl.rc('text', usetex=True)

# %%
import pyGadget

# %% [markdown]
# ## Density structure zoom-in to central minihalo

# %% [markdown]
# Use the final snapshot of the vanilla simulation.

# %%
imzoom = []

# %%
sim = pyGadget.sim.Simulation('stampede/vanilla')

sim.refine_by_mass(False)
sim.set_coordinate_system('physical')

snap = sim.load_snapshot(1900)
print snap.header.Redshift
for scale in ['5376pc','1000pc','100pc']:
    imzoom.append(pyGadget.visualize.project(snap, 'ndensity', scale, 'xz', centering='max'))
snap.close()
# Out:
# 25.03796438
# ...
# Calculating...
# Density maximum box center: 2.761e+03 2.757e+03 2.722e+03
#  x:: max: 2.688e+03 min: -2.688e+03
#  y:: max: 2.688e+03 min: -2.688e+03
# ndensity:: min: 1.523e-03 max: 1.260e+02
# log(ndensity):: min: -2.817e+00 max: 2.100e+00
# Calculating...
# Density maximum box center: 0.000e+00 0.000e+00 0.000e+00
#  x:: max: 5.000e+02 min: -5.000e+02
#  y:: max: 5.000e+02 min: -5.000e+02
# ndensity:: min: 1.954e-03 max: 7.157e+03
# log(ndensity):: min: -2.709e+00 max: 3.855e+00
# Calculating...
# Density maximum box center: 0.000e+00 0.000e+00 0.000e+00
#  x:: max: 5.000e+01 min: -5.000e+01
#  y:: max: 5.000e+01 min: -5.000e+01
# ndensity:: min: 1.345e-01 max: 2.174e+06
# log(ndensity):: min: -8.714e-01 max: 6.337e+00

# %%
sim = pyGadget.sim.Simulation('stampede/halo1_cr05')

sim.refine_by_mass(False)
sim.set_coordinate_system('physical')

snap = sim.load_snapshot(1610)
print snap.header.Redshift
for scale in ['4652pc','1000pc','100pc']:
    imzoom.append(pyGadget.visualize.project(snap, 'ndensity', scale, 'xz', centering='max'))
snap.close()
# Out:
# 29.0947169655
# ...
# Calculating...
# Density maximum box center: 2.380e+03 2.392e+03 2.360e+03
#  x:: max: 2.326e+03 min: -2.326e+03
#  y:: max: 2.326e+03 min: -2.326e+03
# ndensity:: min: 2.487e-03 max: 1.104e+02
# log(ndensity):: min: -2.604e+00 max: 2.043e+00
# Calculating...
# Density maximum box center: 0.000e+00 0.000e+00 0.000e+00
#  x:: max: 5.000e+02 min: -5.000e+02
#  y:: max: 5.000e+02 min: -5.000e+02
# ndensity:: min: 2.845e-03 max: 9.391e+03
# log(ndensity):: min: -2.546e+00 max: 3.973e+00
# Calculating...
# Density maximum box center: 0.000e+00 0.000e+00 0.000e+00
#  x:: max: 5.000e+01 min: -5.000e+01
#  y:: max: 5.000e+01 min: -5.000e+01
# ndensity:: min: 9.037e-02 max: 9.233e+05
# log(ndensity):: min: -1.044e+00 max: 5.965e+00

# %%
sim = pyGadget.sim.Simulation('stampede/halo2_vanilla')

sim.refine_by_mass(False)
sim.set_coordinate_system('physical')

snap = sim.load_snapshot(144)
print snap.header.Redshift
for scale in ['6109pc','1000pc']:
    imzoom.append(pyGadget.visualize.project(snap, 'ndensity', scale, 'xz', centering='max'))
snap.close()

sim.refine_by_mass(True)
snap = sim.load_snapshot(1916)
print snap.header.Redshift
imzoom.append(pyGadget.visualize.project(snap, 'ndensity', '100pc', 'xz', centering='max'))
snap.close()
# Out:
# 21.9177449655
# ...
# Calculating...
# Density maximum box center: 3.063e+04 3.272e+04 3.145e+04
#  x:: max: 3.054e+03 min: -3.054e+03
#  y:: max: 3.054e+03 min: -3.054e+03
# ndensity:: min: 1.971e-03 max: 5.282e+03
# log(ndensity):: min: -2.705e+00 max: 3.723e+00
# Calculating...
# Density maximum box center: 0.000e+00 0.000e+00 0.000e+00
#  x:: max: 5.000e+02 min: -5.000e+02
#  y:: max: 5.000e+02 min: -5.000e+02
# ndensity:: min: 2.950e-03 max: 2.426e+03
# log(ndensity):: min: -2.530e+00 max: 3.385e+00
# Turning on gas particle refinement.
# There are 10560803 highest resolution particles.
# 21.6994570162
# ...
# Calculating...
# Density maximum box center: 3.828e+02 3.718e+02 3.942e+02
#  x:: max: 5.000e+01 min: -5.000e+01
#  y:: max: 5.000e+01 min: -5.000e+01
# ndensity:: min: 1.667e-01 max: 5.434e+06
# log(ndensity):: min: -7.781e-01 max: 6.735e+00

# %%
sim = pyGadget.sim.Simulation('stampede/halo2_cr05')

sim.refine_by_mass(False)
sim.set_coordinate_system('physical')

snap = sim.load_snapshot(97)
print snap.header.Redshift
for scale in ['5000pc','1000pc']:
    imzoom.append(pyGadget.visualize.project(snap, 'ndensity', scale, 'xz', centering='max'))
snap.close()

sim.refine_by_mass(True)
snap = sim.load_snapshot(1747)
print snap.header.Redshift
imzoom.append(pyGadget.visualize.project(snap, 'ndensity', '100pc', 'xz', centering='max'))
snap.close()
# Out:
# 26.9962204026
# ...
# Calculating...
# Density maximum box center: 2.554e+04 2.538e+04 2.531e+04
#  x:: max: 2.500e+03 min: -2.500e+03
#  y:: max: 2.500e+03 min: -2.500e+03
# ndensity:: min: 3.307e-03 max: 1.425e+02
# log(ndensity):: min: -2.481e+00 max: 2.154e+00
# Calculating...
# Density maximum box center: 0.000e+00 0.000e+00 0.000e+00
#  x:: max: 5.000e+02 min: -5.000e+02
#  y:: max: 5.000e+02 min: -5.000e+02
# ndensity:: min: 7.782e-03 max: 1.797e+03
# log(ndensity):: min: -2.109e+00 max: 3.255e+00
# Turning on gas particle refinement.
# There are 6151287 highest resolution particles.
# 26.791801243
# ...
# Calculating...
# Density maximum box center: 2.915e+02 2.983e+02 2.970e+02
#  x:: max: 5.000e+01 min: -5.000e+01
#  y:: max: 5.000e+01 min: -5.000e+01
# ndensity:: min: 1.073e-01 max: 1.434e+06
# log(ndensity):: min: -9.696e-01 max: 6.157e+00

# %%
len(imzoom)
# Out:
# 12

# %%
from mpl_toolkits.axes_grid1 import ImageGrid

scales = ['140 kpc (comoving)', '1 kpc (physical)', '100 pc (physical)']*4
halo = [None, r'Halo 1 $u_{\rm \tiny CR} = 0$',  None, 
        None, r'Halo 1 $u_{\rm \tiny CR} = 10^5 u_0$', None, 
        None, r'Halo 2 $u_{\rm \tiny CR} = 0$', None, 
        None, r'Halo 2 $u_{\rm \tiny CR} = 10^5 u_0$', None]
ratio = [.186, .1, None, .215, .1, None, .1637, .1, None, .2, .1, None]
zoom = ['right', 'right', None]*4
clims = [(-2.5,1.5), (-2.,2.), (-0.5,5.)]*4
ticks = [(-2,-1,0,1), (-1,0,1), (0,1,2,3,4)]*4
cpad = [-17, -17, -17]*4
clabel = [False, False, True]*4
bbox_props = dict(boxstyle="round", fc="k", ec="k", alpha=0.5)
zc = 'w'
zls = '--'
zlw = 1.5

fig = plt.figure(1, (18., 24.), dpi=600)
grid = ImageGrid(fig, 111, # similar to subplot(111)
                nrows_ncols = (4, 3), # creates 2x2 grid of axes
                axes_pad=0.0, # pad between axes in inch.
                cbar_mode = 'each', cbar_size='7%', cbar_pad=0.
                )

for i in range(12):
    x = imzoom[i][0]
    y = imzoom[i][1]
    im = imzoom[i][2]
    ax = grid[i]
    img = ax.imshow(im, cmap=plt.cm.inferno, origin='lower')
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    img.set_clim(clims[i])
    
    cb = plt.colorbar(img, cax=grid.cbar_axes[i])
    cb.set_ticks(ticks[i])
    cb.ax.tick_params(left='on', pad=cpad[i],
                      labelsize=15, labelcolor='k', labelleft='on', labelright='off')
    if clabel[i]: cb.set_label('Log Number Density [cm$^{-3}$]')
        
    ax.text(0.5, 0.025, scales[i], color='w', ha='center', va='bottom', size=12, 
            transform=grid[i].transAxes, bbox=bbox_props)
    if halo[i]:
        ax.text(0.5, 0.95, halo[i], color='w', ha='center', va='top', size=20, 
                transform=grid[i].transAxes, bbox=bbox_props)
    
    if ratio[i]:
        axmin, axmax = ax.get_xlim()
        axlength = axmax - axmin
        mid = axlength/2
        s = ratio[i] * axlength
        s00 = [mid - s/2, mid - s/2]
        s01 = [mid - s/2, mid + s/2]
        s11 = [mid + s/2, mid + s/2]
        ax.add_line(plt.Line2D(s00, s01, c=zc, lw=zlw))
        ax.add_line(plt.Line2D(s11, s01, c=zc, lw=zlw))
        ax.add_line(plt.Line2D(s01, s00, c=zc, lw=zlw))
        ax.add_line(plt.Line2D(s01, s11, c=zc, lw=zlw))
        if zoom[i] == 'right':
            ax.add_line(plt.Line2D([mid+s/2, axmax], [mid+s/2, axmax], c=zc, lw=zlw, ls=zls))
            ax.add_line(plt.Line2D([mid+s/2, axmax], [mid-s/2, axmin], c=zc, lw=zlw, ls=zls))
        elif zoom[i] == 'down':
            ax.add_line(plt.Line2D([mid-s/2, axmin], [mid-s/2, axmin], c=zc, lw=zlw, ls=zls))
            ax.add_line(plt.Line2D([mid+s/2, axmax], [mid-s/2, axmin], c=zc, lw=zlw, ls=zls))
        elif zoom[i] == 'left':
            ax.add_line(plt.Line2D([mid-s/2, axmin], [mid+s/2, axmax], c=zc, lw=zlw, ls=zls))
            ax.add_line(plt.Line2D([mid-s/2, axmin], [mid-s/2, axmin], c=zc, lw=zlw, ls=zls))
plt.show()
fig.savefig('figures/structure/structure.pdf', bbox_inches='tight', dpi=100)

# %%
imzoom[1][2].min()
# Out:
# -2.7089644266371544

# %%
fig,ax = plt.subplots(figsize=(10,10), dpi=600)
img = ax.imshow(imzoom[1][2], cmap=plt.cm.inferno, origin='lower')
img.set_clim((-2.5,3.))
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
fig.savefig('figures/structure/structure_halo.png', bbox_inches='tight', dpi=600)

# %%
fig,ax = plt.subplots(figsize=(10,10), dpi=300)
ax.imshow(imzoom[1][2], cmap=plt.cm.inferno)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
